# %% [markdown]
# # Ex -

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4.

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %% [markdown]
# ### Step 5.

# %%
df.dropna(axis=0, inplace=True)

# %% [markdown]
# ### Step 6.

# %%
df.duplicated().any()
# Out:
# True

# %% [markdown]
# ### Step 7.

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Step 8.

# %%
df['item_name'].value_counts()
# Out:
# item_name
# Chicken Bowl             717
# Chicken Burrito          546
# Steak Burrito            365
# Canned Soft Drink        290
# Steak Bowl               210
# Chicken Soft Tacos       111
# Chicken Salad Bowl       110
# Canned Soda              102
# Veggie Burrito            95
# Barbacoa Burrito          90
# Veggie Bowl               85
# Carnitas Bowl             68
# Barbacoa Bowl             65
# Carnitas Burrito          59
# Steak Soft Tacos          55
# 6 Pack Soft Drink         54
# Chicken Crispy Tacos      47
# Carnitas Soft Tacos       40
# Steak Crispy Tacos        35
# Steak Salad Bowl          29
# Nantucket Nectar          27
# Barbacoa Soft Tacos       25
# Izze                      19
# Veggie Salad Bowl         18
# Barbacoa Crispy Tacos     11
# Chicken Salad              9
# Barbacoa Salad Bowl        9
# Carnitas Crispy Tacos      7
# Veggie Soft Tacos          7
# Burrito                    6
# Carnitas Salad Bowl        6
# ...

# %% [markdown]
# ### Step 9.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(df['quantity'])
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_18720\417376719.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['quantity'])
# <Axes: xlabel='quantity', ylabel='Density'>

# %% [markdown]
# ### Step 10.

# %%
plt.figure(figsize=(24,6))
sns.countplot(data=df, x='item_name')
plt.show()

# %% [markdown]
# ### Step 11.

# %%
plt.figure(figsize=(40,30))
plt.hist(x=df['item_price'])
plt.show()

# %% [markdown]
# ### Step 12.

# %%
plt.figure(figsize=(10,7))
plt.scatter(df['order_id'], df['quantity'])
plt.show()

# %% [markdown]
# ### Step 13.

# %%
plt.figure(figsize=(10,7))
plt.scatter(df['item_price'], df['quantity'])
plt.show()

# %% [markdown]
# ### Step 14.

# %%
plt.figure(figsize=(10,7))
plt.scatter(df['item_price'], df['order_id'])
plt.show()

# %% [markdown]
# ### Step 15.

# %%
plt.figure(figsize=(24,6))
sns.countplot(data=df, x='choice_description')
plt.show()

# %% [markdown]
# ### Step 16.

# %%
plt.figure(figsize=(40,30))
plt.hist(x=df['quantity'])
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
plt.figure(figsize=(50,30))
plt.hist(x=df['order_id'])
plt.show()
